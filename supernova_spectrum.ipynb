# %%
from supernovaSpectrum import *
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

eNu = np.linspace(1.806,50,200)
supernovaGen = SupernovaSpectrum(eNu)

eNuSpectrum = supernovaGen.shootEnu(100000)
plt.hist(eNuSpectrum,100)
plt.show()

# %%
from ibdFirstOrder import *
import util
ibdGen = FirstOrder(10)
cosTheta = ibdGen.shootPosAngle(100000)

enPos, kN, cosPhi = util.getIbdAll(10, cosTheta)

plt.hist(cosPhi, 200)
plt.show()

# %%
from ibdFromSupernova import *
gen = IBDFromSupernova()
gen.shoot(10000)
# Out:
# Complete!

# %%
cosPos, enPos, cosN, kinN = gen.get()

# %%
import util
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

enPos2 = util.getdF_dEnu(np.linspace(0,55,200))*util.getdSigma_dEpos(np.linspace(1.806,55,200))
dSigma_dEpos = util.getdSigma_dEpos(np.linspace(1.806,55,200))
ePosLin = np.linspace(0,53.2,200)# - util.DELT
plt.plot(ePosLin, enPos2)

# %%
enPos3 = util.getdF_dEnu(np.linspace(1.806,50,200))*util.getdSigma_denPos2(np.linspace(1.806,50,200), 0.4)
plt.plot(ePosLin, enPos3)

# %%
enNu = util.getdF_dEnu(np.linspace(0,55,200))
plt.plot(np.linspace(0,55,200),enNu)

# %%
dSigma = util.getdSigma_dEpos(np.linspace(1.806,55,200))
plt.plot(np.linspace(0,53.2,200),dSigma)
