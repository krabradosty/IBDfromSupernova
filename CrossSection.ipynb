# %%
import util
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
eNuLin = np.linspace(1.806,100,200)
sigmaVogel = util.getSigmaVogel(eNuLin)
sigmaFromGd = util.sigmaFromGd(eNuLin)
sigmaStrumia = util.getSigmaStrumia(eNuLin)
plt.plot(eNuLin, sigmaVogel, label='vogel')
plt.plot(eNuLin, sigmaFromGd, label='gd')
plt.plot(eNuLin, sigmaStrumia, label='strumia')
plt.legend()
